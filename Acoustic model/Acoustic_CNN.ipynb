# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import pandas as pd
from datetime import datetime
from termcolor import colored

# %%
# Timer.
startTime = datetime.now()

# Path to created json file from mel preprocess and feature extraction script.
DATA_PATH = "E:/Acoustic/mfcc_data.json"

# Path to save model.
MODEL_SAVE = 'E:/Acoustic/model_1.h5'

# Path to save training history and model accuracy performance at end of training.
HISTORY_SAVE = "E:/Acoustic/history_1.csv"
ACC_SAVE = "E:/Acoustic/models_acc_1.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)
    # Convert lists to numpy arrays.
    X = np.array(data["mfcc"])  # The name in brackets is changed to "mfccs" if MFCC features are used to train.
    y = np.array(data["labels"])
    return X, y


def prepare_datasets(test_size, validation_size):
    # Load extracted features and labels data.
    X, y = load_data(DATA_PATH)

    # Create train/test split.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # Create train/validation split.
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # 3D array.
    X_train = X_train[..., np.newaxis]  # 4-dim array: (# samples, # time steps, # coefficients, 1)
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    # Create model
    model = keras.Sequential()

    # 1st convolutional layer.
    model.add(keras.layers.Conv2D(8, (5, 5), activation='relu', input_shape=input_shape))
        # 8 kernals, and 5x5 grid size of kernal
    model.add(keras.layers.MaxPool2D((5, 5), strides=(2, 2), padding='same'))
        # pooling size 5x5
    model.add(keras.layers.BatchNormalization())
        # Batch Normalization allows model to be more accurate and computations are faster.

    # 2nd convolutional layer.
    model.add(keras.layers.Conv2D(32, (5, 5), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((5, 5), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # Flatten the output and feed into dense layer.
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(32, activation='relu'))
        # 32 = number of neurons
    model.add(keras.layers.Dropout(0.3))
    # Reduces chances of over fitting.

    # Output layer that uses softmax activation.
    model.add(keras.layers.Dense(2, activation='softmax'))
        # 2 neurons --> depends on how many categories we want to predict.

    return model


def predict(model, X, y):
    # Random prediction post-training.
    X = X[np.newaxis, ...]

    prediction = model.predict(X)

    # Extract index with max value.
    predicted_index = np.argmax(prediction, axis=1)
    print("Expected index: {}, Predicted index: {}".format(y, predicted_index))


if __name__ == "__main__":
    # Create train, validation and test sets.
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)  # (test size, val size)

    # Early stopping.
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

    # Checkpoint.
    checkpoint = keras.callbacks.ModelCheckpoint(MODEL_SAVE, monitor='val_loss',
                                                 mode='min', save_best_only=True, verbose=1)

    # Build the CNN network.
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    model = build_model(input_shape)

    # Compile the network.
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                  loss="sparse_categorical_crossentropy",
                  metrics=['accuracy'])

    model.summary()

    # Train the CNN.
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=16, epochs=1000,
                        callbacks=[callback, checkpoint])

    # Save history.
    hist = pd.DataFrame(history.history)

    # Save to csv:
    hist_csv = HISTORY_SAVE
    with open(hist_csv, mode='w') as f:
        hist.to_csv(f)

    print(
        colored("CRNN model has been trained and its training history has been saved to {}.".format(hist_csv), "green"))

    # Evaluate the CNN on the test set.
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
    print("Accuracy on test set is: {}".format(test_accuracy))

    # Timer output.
    time = datetime.now() - startTime
    print(time)

    # Make prediction on a random sample.
    X = X_test[100]
    y = y_test[100]
    predict(model, X, y)

    # Save model accuracies on test set (for weight calculations later on).
    accuracy = {
        "model_acc": [],
        "total_train_time": [],
    }

    accuracy["model_acc"].append(test_accuracy)
    accuracy["total_train_time"].append(str(time))

    with open(ACC_SAVE, "w") as fp:
        json.dump(accuracy, fp, indent=4)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 16, 8)         208
#
#  max_pooling2d (MaxPooling2D  (None, 20, 8, 8)         0
#  )
#
#  batch_normalization (BatchN  (None, 20, 8, 8)         32
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 16, 4, 32)         6432
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 2, 32)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 8, 2, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 32)                16416
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 23,282
# Trainable params: 23,202
# Non-trainable params: 80
# _________________________________________________________________
# Epoch 1/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6216 - accuracy: 0.6683
# Epoch 1: val_loss improved from inf to 0.97975, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 6s 232ms/step - loss: 0.5930 - accuracy: 0.7059 - val_loss: 0.9798 - val_accuracy: 0.4531
# Epoch 2/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3240 - accuracy: 0.8606
# Epoch 2: val_loss improved from 0.97975 to 0.86510, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.3505 - accuracy: 0.8549 - val_loss: 0.8651 - val_accuracy: 0.4844
# Epoch 3/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2637 - accuracy: 0.9087
# Epoch 3: val_loss improved from 0.86510 to 0.77604, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2503 - accuracy: 0.9098 - val_loss: 0.7760 - val_accuracy: 0.5312
# Epoch 4/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1749 - accuracy: 0.9471
# Epoch 4: val_loss improved from 0.77604 to 0.71189, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1752 - accuracy: 0.9490 - val_loss: 0.7119 - val_accuracy: 0.5156
# Epoch 5/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1620 - accuracy: 0.9519
# Epoch 5: val_loss improved from 0.71189 to 0.62785, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1714 - accuracy: 0.9373 - val_loss: 0.6278 - val_accuracy: 0.5938
# Epoch 6/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1199 - accuracy: 0.9663
# Epoch 6: val_loss improved from 0.62785 to 0.55544, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1080 - accuracy: 0.9725 - val_loss: 0.5554 - val_accuracy: 0.6719
# Epoch 7/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1014 - accuracy: 0.9663
# Epoch 7: val_loss improved from 0.55544 to 0.46508, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0963 - accuracy: 0.9725 - val_loss: 0.4651 - val_accuracy: 0.7656
# Epoch 8/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0943 - accuracy: 0.9808
# Epoch 8: val_loss improved from 0.46508 to 0.39025, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0858 - accuracy: 0.9843 - val_loss: 0.3902 - val_accuracy: 0.8438
# Epoch 9/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0774 - accuracy: 0.9808
# Epoch 9: val_loss improved from 0.39025 to 0.30874, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0786 - accuracy: 0.9804 - val_loss: 0.3087 - val_accuracy: 0.8750
# Epoch 10/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0485 - accuracy: 0.9952
# Epoch 10: val_loss improved from 0.30874 to 0.23910, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0510 - accuracy: 0.9961 - val_loss: 0.2391 - val_accuracy: 0.9219
# Epoch 11/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0390 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.23910 to 0.18280, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9375
# Epoch 12/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0397 - accuracy: 0.9952
# Epoch 12: val_loss improved from 0.18280 to 0.13840, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0472 - accuracy: 0.9922 - val_loss: 0.1384 - val_accuracy: 0.9375
# Epoch 13/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0314 - accuracy: 0.9952
# Epoch 13: val_loss improved from 0.13840 to 0.10593, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0337 - accuracy: 0.9922 - val_loss: 0.1059 - val_accuracy: 0.9688
# Epoch 14/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0210 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.10593 to 0.08093, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9688
# Epoch 15/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0288 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.08093 to 0.06421, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9844
# Epoch 16/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0335 - accuracy: 0.9952
# Epoch 16: val_loss improved from 0.06421 to 0.04767, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0305 - accuracy: 0.9961 - val_loss: 0.0477 - val_accuracy: 0.9844
# Epoch 17/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0294 - accuracy: 0.9904
# Epoch 17: val_loss improved from 0.04767 to 0.03532, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0265 - accuracy: 0.9922 - val_loss: 0.0353 - val_accuracy: 0.9844
# Epoch 18/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.03532 to 0.02670, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0198 - accuracy: 0.9961 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 19/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0202 - accuracy: 0.9952
# Epoch 19: val_loss improved from 0.02670 to 0.01942, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0181 - accuracy: 0.9961 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 20/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.01942 to 0.01517, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 21/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.01517 to 0.01226, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 22/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.01226 to 0.00990, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 23/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0158 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00990 to 0.00727, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 24/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00727 to 0.00595, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 25/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00595 to 0.00504, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 26/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00504 to 0.00436, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 27/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00436 to 0.00399, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 28/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00399 to 0.00365, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 29/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0139 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.00365 to 0.00288, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 30/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00288 to 0.00235, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 31/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00235 to 0.00201, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0587 - accuracy: 0.9882 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 32/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.00201
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 33/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0288 - accuracy: 0.9856
# Epoch 33: val_loss improved from 0.00201 to 0.00198, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0248 - accuracy: 0.9882 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 34/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00198 to 0.00145, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 35/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.00145 to 0.00127, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 36/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.00127 to 0.00111, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 37/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.00111 to 0.00099, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 9.8710e-04 - val_accuracy: 1.0000
# Epoch 38/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.00099 to 0.00093, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 9.2749e-04 - val_accuracy: 1.0000
# Epoch 39/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.00093 to 0.00086, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 8.5984e-04 - val_accuracy: 1.0000
# Epoch 40/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00086 to 0.00080, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 8.0082e-04 - val_accuracy: 1.0000
# Epoch 41/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0192 - accuracy: 0.9952
# Epoch 41: val_loss improved from 0.00080 to 0.00069, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0169 - accuracy: 0.9961 - val_loss: 6.9166e-04 - val_accuracy: 1.0000
# Epoch 42/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0149 - accuracy: 0.9904
# Epoch 42: val_loss improved from 0.00069 to 0.00063, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0154 - accuracy: 0.9922 - val_loss: 6.3355e-04 - val_accuracy: 1.0000
# Epoch 43/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0103 - accuracy: 0.9952
# Epoch 43: val_loss improved from 0.00063 to 0.00058, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0087 - accuracy: 0.9961 - val_loss: 5.8455e-04 - val_accuracy: 1.0000
# Epoch 44/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 44: val_loss improved from 0.00058 to 0.00056, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 5.6271e-04 - val_accuracy: 1.0000
# Epoch 45/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.00056 to 0.00054, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 5.4404e-04 - val_accuracy: 1.0000
# Epoch 46/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 46: val_loss improved from 0.00054 to 0.00051, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 5.1212e-04 - val_accuracy: 1.0000
# Epoch 47/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 47: val_loss improved from 0.00051 to 0.00049, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 4.9059e-04 - val_accuracy: 1.0000
# Epoch 48/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.00049 to 0.00047, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 4.6722e-04 - val_accuracy: 1.0000
# Epoch 49/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.00047 to 0.00045, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 4.4918e-04 - val_accuracy: 1.0000
# Epoch 50/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00045
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0195 - accuracy: 0.9922 - val_loss: 4.6562e-04 - val_accuracy: 1.0000
# Epoch 51/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.00045
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 5.3421e-04 - val_accuracy: 1.0000
# Epoch 52/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0176 - accuracy: 0.9952
# Epoch 52: val_loss did not improve from 0.00045
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0147 - accuracy: 0.9961 - val_loss: 6.6216e-04 - val_accuracy: 1.0000
# Epoch 53/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.00045
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 5.7915e-04 - val_accuracy: 1.0000
# Epoch 54/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.00045
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 5.1292e-04 - val_accuracy: 1.0000
# Epoch 55/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 55: val_loss did not improve from 0.00045
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 4.6512e-04 - val_accuracy: 1.0000
# Epoch 56/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 56: val_loss improved from 0.00045 to 0.00039, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.9351e-04 - val_accuracy: 1.0000
# Epoch 57/1000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 57: val_loss improved from 0.00039 to 0.00035, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 3.4869e-04 - val_accuracy: 1.0000
# Epoch 58/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 58: val_loss improved from 0.00035 to 0.00033, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.2841e-04 - val_accuracy: 1.0000
# Epoch 59/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 59: val_loss improved from 0.00033 to 0.00031, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.0728e-04 - val_accuracy: 1.0000
# Epoch 60/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 60: val_loss improved from 0.00031 to 0.00029, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.9106e-04 - val_accuracy: 1.0000
# Epoch 61/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 61: val_loss improved from 0.00029 to 0.00027, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.7303e-04 - val_accuracy: 1.0000
# Epoch 62/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 62: val_loss improved from 0.00027 to 0.00026, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.6009e-04 - val_accuracy: 1.0000
# Epoch 63/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 63: val_loss improved from 0.00026 to 0.00025, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.4912e-04 - val_accuracy: 1.0000
# Epoch 64/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 64: val_loss improved from 0.00025 to 0.00024, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.4213e-04 - val_accuracy: 1.0000
# Epoch 65/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 65: val_loss improved from 0.00024 to 0.00023, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.3061e-04 - val_accuracy: 1.0000
# Epoch 66/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 66: val_loss improved from 0.00023 to 0.00022, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.2379e-04 - val_accuracy: 1.0000
# Epoch 67/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.00022
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.2829e-04 - val_accuracy: 1.0000
# Epoch 68/1000
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 68: val_loss improved from 0.00022 to 0.00022, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.1700e-04 - val_accuracy: 1.0000
# Epoch 69/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 69: val_loss improved from 0.00022 to 0.00021, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.1071e-04 - val_accuracy: 1.0000
# Epoch 70/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 70: val_loss improved from 0.00021 to 0.00021, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.0685e-04 - val_accuracy: 1.0000
# Epoch 71/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 71: val_loss improved from 0.00021 to 0.00020, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.9772e-04 - val_accuracy: 1.0000
# Epoch 72/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 72: val_loss improved from 0.00020 to 0.00018, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.8327e-04 - val_accuracy: 1.0000
# Epoch 73/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 73: val_loss improved from 0.00018 to 0.00017, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.7206e-04 - val_accuracy: 1.0000
# Epoch 74/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 74: val_loss improved from 0.00017 to 0.00017, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.6914e-04 - val_accuracy: 1.0000
# Epoch 75/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 75: val_loss improved from 0.00017 to 0.00016, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.6326e-04 - val_accuracy: 1.0000
# Epoch 76/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0056 - accuracy: 0.9952
# Epoch 76: val_loss improved from 0.00016 to 0.00016, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0049 - accuracy: 0.9961 - val_loss: 1.6304e-04 - val_accuracy: 1.0000
# Epoch 77/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.00016
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.6784e-04 - val_accuracy: 1.0000
# Epoch 78/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 78: val_loss improved from 0.00016 to 0.00016, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.5999e-04 - val_accuracy: 1.0000
# Epoch 79/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 9.7277e-04 - accuracy: 1.0000
# Epoch 79: val_loss improved from 0.00016 to 0.00015, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 9.5712e-04 - accuracy: 1.0000 - val_loss: 1.5252e-04 - val_accuracy: 1.0000
# Epoch 80/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 80: val_loss improved from 0.00015 to 0.00015, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.4574e-04 - val_accuracy: 1.0000
# Epoch 81/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 81: val_loss improved from 0.00015 to 0.00014, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.4119e-04 - val_accuracy: 1.0000
# Epoch 82/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 82: val_loss improved from 0.00014 to 0.00014, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0071 - accuracy: 0.9961 - val_loss: 1.3988e-04 - val_accuracy: 1.0000
# Epoch 83/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.00014
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.9339e-04 - val_accuracy: 1.0000
# Epoch 84/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.00014
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.6427e-04 - val_accuracy: 1.0000
# Epoch 85/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.00014
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.5093e-04 - val_accuracy: 1.0000
# Epoch 86/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.00014
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3991e-04 - val_accuracy: 1.0000
# Epoch 87/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 87: val_loss improved from 0.00014 to 0.00013, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3069e-04 - val_accuracy: 1.0000
# Epoch 88/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 9.2389e-04 - accuracy: 1.0000
# Epoch 88: val_loss improved from 0.00013 to 0.00012, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 7.8859e-04 - accuracy: 1.0000 - val_loss: 1.2433e-04 - val_accuracy: 1.0000
# Epoch 89/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0121 - accuracy: 0.9952
# Epoch 89: val_loss did not improve from 0.00012
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0099 - accuracy: 0.9961 - val_loss: 1.5305e-04 - val_accuracy: 1.0000
# Epoch 90/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.00012
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.5437e-04 - val_accuracy: 1.0000
# Epoch 91/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 91: val_loss did not improve from 0.00012
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.3907e-04 - val_accuracy: 1.0000
# Epoch 92/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 92: val_loss did not improve from 0.00012
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.8400e-04 - val_accuracy: 1.0000
# Epoch 93/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0119 - accuracy: 0.9952
# Epoch 93: val_loss did not improve from 0.00012
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0100 - accuracy: 0.9961 - val_loss: 1.3019e-04 - val_accuracy: 1.0000
# Epoch 94/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 94: val_loss improved from 0.00012 to 0.00012, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 32ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1951e-04 - val_accuracy: 1.0000
# Epoch 95/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 95: val_loss improved from 0.00012 to 0.00011, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.0978e-04 - val_accuracy: 1.0000
# Epoch 96/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 96: val_loss improved from 0.00011 to 0.00010, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0049e-04 - val_accuracy: 1.0000
# Epoch 97/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 97: val_loss improved from 0.00010 to 0.00009, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 9.1213e-05 - val_accuracy: 1.0000
# Epoch 98/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 98: val_loss improved from 0.00009 to 0.00008, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 8.4632e-05 - val_accuracy: 1.0000
# Epoch 99/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 99: val_loss improved from 0.00008 to 0.00008, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 7.5524e-05 - val_accuracy: 1.0000
# Epoch 100/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 100: val_loss improved from 0.00008 to 0.00007, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 7.4376e-05 - val_accuracy: 1.0000
# Epoch 101/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 7.4581e-04 - accuracy: 1.0000
# Epoch 101: val_loss improved from 0.00007 to 0.00007, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 7.2987e-04 - accuracy: 1.0000 - val_loss: 7.1591e-05 - val_accuracy: 1.0000
# Epoch 102/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 102: val_loss improved from 0.00007 to 0.00007, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 6.7961e-05 - val_accuracy: 1.0000
# Epoch 103/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 103: val_loss improved from 0.00007 to 0.00006, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 6.4594e-05 - val_accuracy: 1.0000
# Epoch 104/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 104: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 6.7551e-05 - val_accuracy: 1.0000
# Epoch 105/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 105: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.7826e-05 - val_accuracy: 1.0000
# Epoch 106/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.3707e-04 - accuracy: 1.0000
# Epoch 106: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 18ms/step - loss: 6.2987e-04 - accuracy: 1.0000 - val_loss: 6.5434e-05 - val_accuracy: 1.0000
# Epoch 107/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0119 - accuracy: 0.9952
# Epoch 107: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0098 - accuracy: 0.9961 - val_loss: 8.9919e-05 - val_accuracy: 1.0000
# Epoch 108/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 9.0653e-04 - accuracy: 1.0000
# Epoch 108: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 19ms/step - loss: 8.3717e-04 - accuracy: 1.0000 - val_loss: 1.0516e-04 - val_accuracy: 1.0000
# Epoch 109/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 7.6918e-04 - accuracy: 1.0000
# Epoch 109: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 19ms/step - loss: 7.2977e-04 - accuracy: 1.0000 - val_loss: 1.0596e-04 - val_accuracy: 1.0000
# Epoch 110/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 110: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.3440e-05 - val_accuracy: 1.0000
# Epoch 111/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 111: val_loss did not improve from 0.00006
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 6.4652e-05 - val_accuracy: 1.0000
# Epoch 112/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 8.6518e-04 - accuracy: 1.0000
# Epoch 112: val_loss improved from 0.00006 to 0.00005, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 9.5973e-04 - accuracy: 1.0000 - val_loss: 4.7767e-05 - val_accuracy: 1.0000
# Epoch 113/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 7.0371e-04 - accuracy: 1.0000
# Epoch 113: val_loss improved from 0.00005 to 0.00005, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 7.1332e-04 - accuracy: 1.0000 - val_loss: 4.5517e-05 - val_accuracy: 1.0000
# Epoch 114/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.7467e-04 - accuracy: 1.0000
# Epoch 114: val_loss improved from 0.00005 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 6.1781e-04 - accuracy: 1.0000 - val_loss: 4.4344e-05 - val_accuracy: 1.0000
# Epoch 115/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.6228e-04 - accuracy: 1.0000
# Epoch 115: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 6.9436e-04 - accuracy: 1.0000 - val_loss: 4.3309e-05 - val_accuracy: 1.0000
# Epoch 116/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 116: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.2806e-05 - val_accuracy: 1.0000
# Epoch 117/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 8.8125e-04 - accuracy: 1.0000
# Epoch 117: val_loss did not improve from 0.00004
# 16/16 [==============================] - 0s 19ms/step - loss: 8.5937e-04 - accuracy: 1.0000 - val_loss: 4.3143e-05 - val_accuracy: 1.0000
# Epoch 118/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 7.1424e-04 - accuracy: 1.0000
# Epoch 118: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 7.8465e-04 - accuracy: 1.0000 - val_loss: 4.2232e-05 - val_accuracy: 1.0000
# Epoch 119/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.1430e-04 - accuracy: 1.0000
# Epoch 119: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 7.7168e-04 - accuracy: 1.0000 - val_loss: 4.0469e-05 - val_accuracy: 1.0000
# Epoch 120/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 120: val_loss did not improve from 0.00004
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.0903e-05 - val_accuracy: 1.0000
# Epoch 121/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 4.0277e-04 - accuracy: 1.0000
# Epoch 121: val_loss did not improve from 0.00004
# 16/16 [==============================] - 0s 19ms/step - loss: 4.3807e-04 - accuracy: 1.0000 - val_loss: 4.0817e-05 - val_accuracy: 1.0000
# Epoch 122/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.6466e-04 - accuracy: 1.0000
# Epoch 122: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 5.8780e-04 - accuracy: 1.0000 - val_loss: 4.0452e-05 - val_accuracy: 1.0000
# Epoch 123/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 123: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.8499e-05 - val_accuracy: 1.0000
# Epoch 124/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 7.5550e-04 - accuracy: 1.0000
# Epoch 124: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 6.6492e-04 - accuracy: 1.0000 - val_loss: 3.5093e-05 - val_accuracy: 1.0000
# Epoch 125/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 125: val_loss did not improve from 0.00004
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.5139e-05 - val_accuracy: 1.0000
# Epoch 126/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.8409e-04 - accuracy: 1.0000
# Epoch 126: val_loss improved from 0.00004 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 5.9370e-04 - accuracy: 1.0000 - val_loss: 3.4980e-05 - val_accuracy: 1.0000
# Epoch 127/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 127: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 4.0856e-05 - val_accuracy: 1.0000
# Epoch 128/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 128: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.1109e-05 - val_accuracy: 1.0000
# Epoch 129/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 4.8526e-04 - accuracy: 1.0000
# Epoch 129: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 19ms/step - loss: 8.3779e-04 - accuracy: 1.0000 - val_loss: 3.5802e-05 - val_accuracy: 1.0000
# Epoch 130/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 3.2588e-04 - accuracy: 1.0000
# Epoch 130: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 3.0803e-04 - accuracy: 1.0000 - val_loss: 3.4183e-05 - val_accuracy: 1.0000
# Epoch 131/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 7.5073e-04 - accuracy: 1.0000
# Epoch 131: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 6.5065e-04 - accuracy: 1.0000 - val_loss: 3.3072e-05 - val_accuracy: 1.0000
# Epoch 132/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 132: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.6864e-05 - val_accuracy: 1.0000
# Epoch 133/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.4542e-04 - accuracy: 1.0000
# Epoch 133: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 9.5732e-04 - accuracy: 1.0000 - val_loss: 2.6222e-05 - val_accuracy: 1.0000
# Epoch 134/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 5.3550e-04 - accuracy: 1.0000
# Epoch 134: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 23ms/step - loss: 4.9547e-04 - accuracy: 1.0000 - val_loss: 2.5432e-05 - val_accuracy: 1.0000
# Epoch 135/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 9.1913e-04 - accuracy: 1.0000
# Epoch 135: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 7.6928e-04 - accuracy: 1.0000 - val_loss: 2.5030e-05 - val_accuracy: 1.0000
# Epoch 136/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 6.7777e-04 - accuracy: 1.0000
# Epoch 136: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 19ms/step - loss: 7.9944e-04 - accuracy: 1.0000 - val_loss: 2.5495e-05 - val_accuracy: 1.0000
# Epoch 137/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 5.7420e-04 - accuracy: 1.0000
# Epoch 137: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 19ms/step - loss: 5.0366e-04 - accuracy: 1.0000 - val_loss: 2.5906e-05 - val_accuracy: 1.0000
# Epoch 138/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 9.7226e-04 - accuracy: 1.0000
# Epoch 138: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 19ms/step - loss: 8.0321e-04 - accuracy: 1.0000 - val_loss: 2.6339e-05 - val_accuracy: 1.0000
# Epoch 139/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 9.2293e-04 - accuracy: 1.0000
# Epoch 139: val_loss did not improve from 0.00003
# 16/16 [==============================] - 0s 18ms/step - loss: 7.9606e-04 - accuracy: 1.0000 - val_loss: 2.5561e-05 - val_accuracy: 1.0000
# Epoch 140/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 2.0526e-04 - accuracy: 1.0000
# Epoch 140: val_loss improved from 0.00003 to 0.00002, saving model to E:/Acoustic\model_1.h5
# 16/16 [==============================] - 0s 29ms/step - loss: 1.8306e-04 - accuracy: 1.0000 - val_loss: 2.4584e-05 - val_accuracy: 1.0000
# Epoch 141/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0134 - accuracy: 0.9952
# Epoch 141: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 7.5716e-05 - val_accuracy: 1.0000
# Epoch 142/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 142: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.9221e-05 - val_accuracy: 1.0000
# Epoch 143/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 4.8129e-04 - accuracy: 1.0000
# Epoch 143: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 4.5467e-04 - accuracy: 1.0000 - val_loss: 9.3067e-05 - val_accuracy: 1.0000
# Epoch 144/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 3.4109e-04 - accuracy: 1.0000
# Epoch 144: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 7.9308e-05 - val_accuracy: 1.0000
# Epoch 145/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 8.4518e-04 - accuracy: 1.0000
# Epoch 145: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 7.1241e-04 - accuracy: 1.0000 - val_loss: 4.3976e-05 - val_accuracy: 1.0000
# Epoch 146/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 3.2415e-04 - accuracy: 1.0000
# Epoch 146: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 3.2904e-04 - accuracy: 1.0000 - val_loss: 3.9464e-05 - val_accuracy: 1.0000
# Epoch 147/1000
# 14/16 [=========================>....] - ETA: 0s - loss: 3.1227e-04 - accuracy: 1.0000
# Epoch 147: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 3.6745e-04 - accuracy: 1.0000 - val_loss: 3.8099e-05 - val_accuracy: 1.0000
# Epoch 148/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 5.6157e-04 - accuracy: 1.0000
# Epoch 148: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 4.9095e-04 - accuracy: 1.0000 - val_loss: 3.8220e-05 - val_accuracy: 1.0000
# Epoch 149/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 3.4220e-04 - accuracy: 1.0000
# Epoch 149: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 4.5476e-04 - accuracy: 1.0000 - val_loss: 3.7865e-05 - val_accuracy: 1.0000
# Epoch 150/1000
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 150: val_loss did not improve from 0.00002
# 16/16 [==============================] - 0s 19ms/step - loss: 8.5761e-04 - accuracy: 1.0000 - val_loss: 3.6018e-05 - val_accuracy: 1.0000
# CRNN model has been trained and its training history has been saved to E:/Acoustic/history_1.csv.
# 4/4 [==============================] - 0s 9ms/step - loss: 9.3476e-05 - accuracy: 1.0000
# Accuracy on test set is: 1.0
# 0:00:59.424780
# 1/1 [==============================] - 0s 169ms/step
# Expected index: 0, Predicted index: [0]

# %%
# Make prediction on a random sample.
X = X_test[45]
y = y_test[45]
predict(model, X, y)

    # Save model accuracies on test set (for weight calculations later on).
accuracy = {
    "model_acc": [],
    "total_train_time": [],
}

accuracy["model_acc"].append(test_accuracy)
accuracy["total_train_time"].append(str(time))

with open(ACC_SAVE, "w") as fp:
    json.dump(accuracy, fp, indent=4)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# Expected index: 0, Predicted index: [0]

# %%
y
# Out:
# 0

# %%
import os
import json
import librosa
import tensorflow as tf
import numpy as np
from termcolor import colored

# Read and save parameters.
DATASET_PATH = "E:/Acoustic_test"  # Path of folder with testing audios
SAVED_MODEL_PATH = "E:/Acoustic/model_1.h5"  # Path of trained model
SAMPLE_RATE = 22050  # Sample rate in Hz.
DURATION = 1  # Length of audio files fed. Measured in seconds.
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# Predictions (1 or 0)
JSON_PATH = "E:/Acoustic_test/predictions.json"
# Performance scores (accuracy, precision, recall, f1 score)
JSON_PERFORMANCE = "E:/Acoustic_test/model_scores.json"

# Prediction of fed audio


class _Class_Predict_Service:
    """Singleton class for keyword spotting inference with trained models.
    :param model: Trained model
    """
    # Mapping so drone = 1.
    model = None
    _mapping = [
        1,
        0
    ]
    _instance = None

    # Predict hard values (1 or 0).
    def predict(self, file_path):
        """
        :param file_path (str): Path to audio file to predict
        :return predicted_keyword (str): Keyword predicted by the model
        """
        print("here")
        # Extract mels from testing audio.
        log_mel = self.preprocess(file_path)

        # We need a 4-dim array to feed to the model for prediction: (# samples, # time steps, # coefficients, 1).
        log_mel = log_mel[np.newaxis, ..., np.newaxis]

        # Get the predicted label.
        predictions = self.model.predict(log_mel)
        predicted_index = np.argmax(predictions)
        predicted_class = self._mapping[predicted_index]
        print(predicted_class)
        return predicted_class

    # Outputs certainty values for soft voting (1-0).

    def preprocess(self, file_path, n_mels=20, n_fft=2048, hop_length=512, num_segments=1):

        num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)

        # Load audio file.
        signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

        # Process segments extracting mels and storing data.
        for s in range(num_segments):
            start_sample = num_samples_per_segment * s  # s=0 --> 0
            # s=0 --> num_samples_per_segment
            finish_sample = start_sample + num_samples_per_segment

            # Extract mel specs.
            mel = librosa.feature.melspectrogram(y=signal[start_sample:finish_sample], sr=sr, n_mels=n_mels, n_fft=n_fft,
                                                 hop_length=hop_length)
            log_mel = librosa.power_to_db(mel)

        return log_mel.T

def Keyword_Spotting_Service():
    """Factory function for Keyword_Spotting_Service class.
    :return _Keyword_Spotting_Service._instance (_Keyword_Spotting_Service):
    """

    # Ensure an instance is created only the first time the factory function is called.
    if _Class_Predict_Service._instance is None:
        _Class_Predict_Service._instance = _Class_Predict_Service()
        _Class_Predict_Service.model = tf.keras.models.load_model(
            SAVED_MODEL_PATH)
    return _Class_Predict_Service._instance


# Saving results into a json file.
def save_mfcc(dataset_path, json_path):
    # Dictionary to store data.
    data = {
        # Maps different class labels --> background is mapped to 0.
        "mapping": [],
        "names": [],
        "results": [],  # mels are the training input, labels are the target.
    }

    # Loop through all the classes.
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # Ensure that we're not at the root level.
        if dirpath is not dataset_path:

            # Save the semantic label.
            # class/background => ["class", "background"]
            dirpath_components = dirpath.split("/")
            # considering only the last value
            semantic_label = dirpath_components[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing {}".format(semantic_label))

            # Process files for a specific class.
            for f in filenames:
                file_path = os.path.join(dirpath, f)

                # Create 2 instances of the keyword spotting service.
                kss = Keyword_Spotting_Service()
                kss1 = Keyword_Spotting_Service()

                # Check that different instances of the keyword spotting service point back to the same object.
                assert kss is kss1

                # Classify unseen audio.
                keyword = kss.predict(file_path)

                # Store mel for segment if it has the expected length.
                data["names"].append(f)
                data["results"].append(keyword)
                print("{}".format(file_path))

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)


# Calculating performance scores (accuracy, precision, recall, f-score).
def performance_calcs(performance_path):
    # Dictionary to store model performance results.
    performance = {
        "TP": [],
        "FN": [],
        "TN": [],
        "FP": [],
        "Accuracy": [],
        "Precision": [],
        "Recall": [],
        "F1 Score": [],
    }

    with open(JSON_PATH, "r") as fp:
        data = json.load(fp)

    # Convert lists to numpy arrays.
    y = np.array(data["results"])

    a = float(sum(y[0:int(len(y) / 2)]))
    b = float(sum(y[int(len(y) / 2):int(len(y))]))

    # Calculating TP, TN, FP, FN.
    TP = a
    FN = int(len(y) / 2) - a
    FP = b
    TN = int(len(y) / 2) - b

    # Performance result calcs.
    Accuracy = (TP + TN) / (TP + TN + FN + FP)
    Precision = TP / (TP + FP)
    Recall = TP / (TP + FN)
    F1 = (2 * Precision * Recall) / (Precision + Recall)

    performance["TP"].append(TP)
    performance["FN"].append(FN)
    performance["TN"].append(TN)
    performance["FP"].append(FP)
    performance["Accuracy"].append(Accuracy)
    performance["Precision"].append(Precision)
    performance["Recall"].append(Recall)
    performance["F1 Score"].append(F1)

    with open(performance_path, "w") as fp:
        json.dump(performance, fp, indent=4)


if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH)
    performance_calcs(JSON_PERFORMANCE)

    print(
        colored("CRNN model performance scores have been saved to {}.".format(JSON_PERFORMANCE), "green"))
# Out:
# C:\Users\Vidyuth\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Vidyuth\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\Vidyuth\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 import json
#       3 import librosa
# ----> 4 import tensorflow as tf
#       5 import numpy as np
#       6 from termcolor import colored
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\__init__.py:38, in <module>
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\__init__.py:42, in <module>
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\__init__.py:21, in <module>
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\experimental\__init__.py:97, in <module>
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      93 @@UNKNOWN_CARDINALITY
#      94 """
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\experimental\service\__init__.py:419, in <module>
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:25, in <module>
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 25 from tensorflow.python.data.ops import dataset_ops
#      26 from tensorflow.python.data.ops import options as options_lib
#      27 from tensorflow.python.data.ops import structured_function
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:31, in <module>
#      29 from tensorflow.python.data.ops import dataset_autograph
#      30 from tensorflow.python.data.ops import debug_mode
# ---> 31 from tensorflow.python.data.ops import iterator_ops
#      32 from tensorflow.python.data.ops import options as options_lib
#      33 from tensorflow.python.data.ops import structured_function
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\iterator_ops.py:40, in <module>
#      38 from tensorflow.python.saved_model import nested_structure_coder
#      39 from tensorflow.python.trackable import base as trackable
# ---> 40 from tensorflow.python.training.saver import BaseSaverBuilder
#      41 from tensorflow.python.util import _pywrap_utils
#      42 from tensorflow.python.util import deprecation
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\training\saver.py:50, in <module>
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\training\py_checkpoint_reader.py:19, in <module>
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      23 def error_translator(e):
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception
