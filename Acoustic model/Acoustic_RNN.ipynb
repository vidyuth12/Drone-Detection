# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import pandas as pd
from datetime import datetime
from termcolor import colored

# Timer.
startTime = datetime.now()

# Path to created json file from mel preprocess and feature extraction script.
DATA_PATH = "E:/Acoustic/mel_data.json"

# Path to save model.
MODEL_SAVE = 'E:/Acoustic/model_1_RNN.h5'

# Path to save training history and model accuracy performance at end of training.
HISTORY_SAVE = "E:/Acoustic/history_1_RNN.csv"
ACC_SAVE = "E:/Acoustic/models_acc_1_RNN.json"

def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # Convert lists to numpy arrays.
    X = np.array(data["mel"]) # The name in brackets is changed to "mfccs" if MFCC features are used to train.
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validation_size):
    # Load extracted features and labels data.
    X, y = load_data(DATA_PATH)

    # Create train/test split.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # Create train/validation split.
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    # Create model.
    model = keras.Sequential()

    # 3 LSTM layers
    model.add(keras.layers.Bidirectional(keras.layers.LSTM(100, return_sequences=True), input_shape=input_shape))
    model.add(keras.layers.Bidirectional(keras.layers.LSTM(100, return_sequences=True), input_shape=(input_shape, 1)))
    model.add(keras.layers.Bidirectional(keras.layers.LSTM(100)))

    # Dense layer
    model.add(keras.layers.Dense(100, activation='relu'))
    model.add(keras.layers.Dropout(0.5))

    # Output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model


if __name__ == "__main__":
    # Create train, validation and test sets.
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # Early stopping.
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

    # Checkpoint.
    checkpoint = keras.callbacks.ModelCheckpoint(MODEL_SAVE, monitor='val_loss',
                                                  mode='min', save_best_only=True, verbose=1)

    # Build the RNN network.
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_model(input_shape)

    # Compile the network.
    optimiser = keras.optimizers.Adam(learning_rate=0.0005)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # Train the RNN.
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=1000,
                          callbacks=[callback, checkpoint])

    # Save history.
    hist = pd.DataFrame(history.history)

    # Save to csv:
    hist_csv = HISTORY_SAVE
    with open(hist_csv, mode='w') as f:
        hist.to_csv(f)

    print(colored("Paper 8's model has been trained and its training history has been saved to {}.".format(hist_csv), "green"))

    # Evaluate the RNN on the test set.
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
    print("Accuracy on test set is: {}".format(test_accuracy))

    # Timer output.
    time = datetime.now() - startTime
    print(time)

    # Save model accuracies on test set.
    accuracy = {
        "model_acc": [],
        "total_train_time": [],
    }

    accuracy["model_acc"].append(test_accuracy)
    accuracy["total_train_time"].append(str(time))

    with open(ACC_SAVE, "w") as fp:
        json.dump(accuracy, fp, indent=4)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 44, 200)          152800
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 44, 200)          240800
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dense (Dense)               (None, 100)               20100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 654,702
# Trainable params: 654,702
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.5724 - accuracy: 0.6863
# Epoch 1: val_loss improved from inf to 0.33190, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 16s 2s/step - loss: 0.5724 - accuracy: 0.6863 - val_loss: 0.3319 - val_accuracy: 0.9688
# Epoch 2/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.9765
# Epoch 2: val_loss improved from 0.33190 to 0.07563, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 3s 850ms/step - loss: 0.2495 - accuracy: 0.9765 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 3/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 1.0000
# Epoch 3: val_loss improved from 0.07563 to 0.01604, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 3s 816ms/step - loss: 0.0619 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 4/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 1.0000
# Epoch 4: val_loss improved from 0.01604 to 0.00339, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 3s 835ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 5/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 5: val_loss improved from 0.00339 to 0.00110, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 3s 847ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 6/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 6: val_loss improved from 0.00110 to 0.00047, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 3s 874ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 4.7247e-04 - val_accuracy: 1.0000
# Epoch 7/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 7: val_loss improved from 0.00047 to 0.00024, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.4493e-04 - val_accuracy: 1.0000
# Epoch 8/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 8: val_loss improved from 0.00024 to 0.00015, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4671e-04 - val_accuracy: 1.0000
# Epoch 9/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.00015 to 0.00010, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 9.8004e-05 - val_accuracy: 1.0000
# Epoch 10/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.0319e-04 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.00010 to 0.00007, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 9.0319e-04 - accuracy: 1.0000 - val_loss: 7.1170e-05 - val_accuracy: 1.0000
# Epoch 11/1000
# 4/4 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.00007 to 0.00006, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.5119e-05 - val_accuracy: 1.0000
# Epoch 12/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.1648e-04 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.00006 to 0.00004, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 6.1648e-04 - accuracy: 1.0000 - val_loss: 4.4829e-05 - val_accuracy: 1.0000
# Epoch 13/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.1506e-04 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.00004 to 0.00004, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 4.1506e-04 - accuracy: 1.0000 - val_loss: 3.7848e-05 - val_accuracy: 1.0000
# Epoch 14/1000
# 4/4 [==============================] - ETA: 0s - loss: 7.3039e-04 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.00004 to 0.00003, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 7.3039e-04 - accuracy: 1.0000 - val_loss: 3.2808e-05 - val_accuracy: 1.0000
# Epoch 15/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.9844e-04 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.9844e-04 - accuracy: 1.0000 - val_loss: 2.8604e-05 - val_accuracy: 1.0000
# Epoch 16/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.8625e-04 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00003 to 0.00003, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 2s/step - loss: 3.8625e-04 - accuracy: 1.0000 - val_loss: 2.5479e-05 - val_accuracy: 1.0000
# Epoch 17/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.8592e-04 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00003 to 0.00002, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.8592e-04 - accuracy: 1.0000 - val_loss: 2.3070e-05 - val_accuracy: 1.0000
# Epoch 18/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.8005e-04 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.00002 to 0.00002, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.8005e-04 - accuracy: 1.0000 - val_loss: 2.1068e-05 - val_accuracy: 1.0000
# Epoch 19/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.1119e-04 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00002 to 0.00002, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.1119e-04 - accuracy: 1.0000 - val_loss: 1.9438e-05 - val_accuracy: 1.0000
# Epoch 20/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.0106e-04 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.00002 to 0.00002, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 4.0106e-04 - accuracy: 1.0000 - val_loss: 1.7959e-05 - val_accuracy: 1.0000
# Epoch 21/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.3715e-04 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.00002 to 0.00002, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.3715e-04 - accuracy: 1.0000 - val_loss: 1.6751e-05 - val_accuracy: 1.0000
# Epoch 22/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.7449e-04 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.00002 to 0.00002, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.7449e-04 - accuracy: 1.0000 - val_loss: 1.5555e-05 - val_accuracy: 1.0000
# Epoch 23/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.1030e-04 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00002 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.1030e-04 - accuracy: 1.0000 - val_loss: 1.4463e-05 - val_accuracy: 1.0000
# Epoch 24/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.8161e-04 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.8161e-04 - accuracy: 1.0000 - val_loss: 1.3551e-05 - val_accuracy: 1.0000
# Epoch 25/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.2246e-04 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.2246e-04 - accuracy: 1.0000 - val_loss: 1.2711e-05 - val_accuracy: 1.0000
# Epoch 26/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.2775e-04 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.2775e-04 - accuracy: 1.0000 - val_loss: 1.1990e-05 - val_accuracy: 1.0000
# Epoch 27/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5472e-04 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 7s 2s/step - loss: 1.5472e-04 - accuracy: 1.0000 - val_loss: 1.1370e-05 - val_accuracy: 1.0000
# Epoch 28/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1871e-04 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 7s 2s/step - loss: 1.1871e-04 - accuracy: 1.0000 - val_loss: 1.0824e-05 - val_accuracy: 1.0000
# Epoch 29/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.3571e-04 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.3571e-04 - accuracy: 1.0000 - val_loss: 1.0285e-05 - val_accuracy: 1.0000
# Epoch 30/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.4591e-04 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.4591e-04 - accuracy: 1.0000 - val_loss: 9.6708e-06 - val_accuracy: 1.0000
# Epoch 31/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.2692e-04 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.2692e-04 - accuracy: 1.0000 - val_loss: 9.1064e-06 - val_accuracy: 1.0000
# Epoch 32/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4782e-04 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.4782e-04 - accuracy: 1.0000 - val_loss: 8.6315e-06 - val_accuracy: 1.0000
# Epoch 33/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.1097e-04 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.1097e-04 - accuracy: 1.0000 - val_loss: 8.1453e-06 - val_accuracy: 1.0000
# Epoch 34/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5258e-04 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.5258e-04 - accuracy: 1.0000 - val_loss: 7.7299e-06 - val_accuracy: 1.0000
# Epoch 35/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.5489e-04 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.5489e-04 - accuracy: 1.0000 - val_loss: 7.3202e-06 - val_accuracy: 1.0000
# Epoch 36/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.8273e-04 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.8273e-04 - accuracy: 1.0000 - val_loss: 6.9067e-06 - val_accuracy: 1.0000
# Epoch 37/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.1061e-04 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.1061e-04 - accuracy: 1.0000 - val_loss: 6.4578e-06 - val_accuracy: 1.0000
# Epoch 38/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.7064e-05 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 9.7064e-05 - accuracy: 1.0000 - val_loss: 6.0666e-06 - val_accuracy: 1.0000
# Epoch 39/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4554e-04 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.4554e-04 - accuracy: 1.0000 - val_loss: 5.7369e-06 - val_accuracy: 1.0000
# Epoch 40/1000
# 4/4 [==============================] - ETA: 0s - loss: 8.5461e-05 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 8.5461e-05 - accuracy: 1.0000 - val_loss: 5.4631e-06 - val_accuracy: 1.0000
# Epoch 41/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.5606e-04 - accuracy: 1.0000
# Epoch 41: val_loss improved from 0.00001 to 0.00001, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.5606e-04 - accuracy: 1.0000 - val_loss: 5.0980e-06 - val_accuracy: 1.0000
# Epoch 42/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.2468e-04 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.00001 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 2s/step - loss: 1.2468e-04 - accuracy: 1.0000 - val_loss: 4.7404e-06 - val_accuracy: 1.0000
# Epoch 43/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.7793e-04 - accuracy: 1.0000
# Epoch 43: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 2s/step - loss: 1.7793e-04 - accuracy: 1.0000 - val_loss: 4.4275e-06 - val_accuracy: 1.0000
# Epoch 44/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4437e-04 - accuracy: 1.0000
# Epoch 44: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 7s 2s/step - loss: 1.4437e-04 - accuracy: 1.0000 - val_loss: 4.1630e-06 - val_accuracy: 1.0000
# Epoch 45/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5531e-04 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.5531e-04 - accuracy: 1.0000 - val_loss: 3.9190e-06 - val_accuracy: 1.0000
# Epoch 46/1000
# 4/4 [==============================] - ETA: 0s - loss: 8.6055e-05 - accuracy: 1.0000
# Epoch 46: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 2s/step - loss: 8.6055e-05 - accuracy: 1.0000 - val_loss: 3.7104e-06 - val_accuracy: 1.0000
# Epoch 47/1000
# 4/4 [==============================] - ETA: 0s - loss: 7.5400e-05 - accuracy: 1.0000
# Epoch 47: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 7.5400e-05 - accuracy: 1.0000 - val_loss: 3.5521e-06 - val_accuracy: 1.0000
# Epoch 48/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0331e-04 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.0331e-04 - accuracy: 1.0000 - val_loss: 3.3956e-06 - val_accuracy: 1.0000
# Epoch 49/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0405e-04 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 1s/step - loss: 1.0405e-04 - accuracy: 1.0000 - val_loss: 3.2484e-06 - val_accuracy: 1.0000
# Epoch 50/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.0566e-05 - accuracy: 1.0000
# Epoch 50: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 2s/step - loss: 6.0566e-05 - accuracy: 1.0000 - val_loss: 3.1162e-06 - val_accuracy: 1.0000
# Epoch 51/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.2418e-05 - accuracy: 1.0000
# Epoch 51: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 1s/step - loss: 9.2418e-05 - accuracy: 1.0000 - val_loss: 3.0082e-06 - val_accuracy: 1.0000
# Epoch 52/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.1949e-04 - accuracy: 1.0000
# Epoch 52: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.1949e-04 - accuracy: 1.0000 - val_loss: 2.8610e-06 - val_accuracy: 1.0000
# Epoch 53/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.6270e-05 - accuracy: 1.0000
# Epoch 53: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.6270e-05 - accuracy: 1.0000 - val_loss: 2.7344e-06 - val_accuracy: 1.0000
# Epoch 54/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.9013e-05 - accuracy: 1.0000
# Epoch 54: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 7s 2s/step - loss: 6.9013e-05 - accuracy: 1.0000 - val_loss: 2.6301e-06 - val_accuracy: 1.0000
# Epoch 55/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.5837e-05 - accuracy: 1.0000
# Epoch 55: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 9.5837e-05 - accuracy: 1.0000 - val_loss: 2.5257e-06 - val_accuracy: 1.0000
# Epoch 56/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5021e-04 - accuracy: 1.0000
# Epoch 56: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.5021e-04 - accuracy: 1.0000 - val_loss: 2.4252e-06 - val_accuracy: 1.0000
# Epoch 57/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1915e-04 - accuracy: 1.0000
# Epoch 57: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.1915e-04 - accuracy: 1.0000 - val_loss: 2.3246e-06 - val_accuracy: 1.0000
# Epoch 58/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.9410e-05 - accuracy: 1.0000
# Epoch 58: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 5.9410e-05 - accuracy: 1.0000 - val_loss: 2.2259e-06 - val_accuracy: 1.0000
# Epoch 59/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1688e-04 - accuracy: 1.0000
# Epoch 59: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.1688e-04 - accuracy: 1.0000 - val_loss: 2.1476e-06 - val_accuracy: 1.0000
# Epoch 60/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.3148e-04 - accuracy: 1.0000
# Epoch 60: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.3148e-04 - accuracy: 1.0000 - val_loss: 2.0452e-06 - val_accuracy: 1.0000
# Epoch 61/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0259e-04 - accuracy: 1.0000
# Epoch 61: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.0259e-04 - accuracy: 1.0000 - val_loss: 1.9539e-06 - val_accuracy: 1.0000
# Epoch 62/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.7026e-05 - accuracy: 1.0000
# Epoch 62: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 4.7026e-05 - accuracy: 1.0000 - val_loss: 1.8775e-06 - val_accuracy: 1.0000
# Epoch 63/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.3034e-05 - accuracy: 1.0000
# Epoch 63: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 5.3034e-05 - accuracy: 1.0000 - val_loss: 1.8217e-06 - val_accuracy: 1.0000
# Epoch 64/1000
# 4/4 [==============================] - ETA: 0s - loss: 7.3248e-05 - accuracy: 1.0000
# Epoch 64: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 7.3248e-05 - accuracy: 1.0000 - val_loss: 1.7583e-06 - val_accuracy: 1.0000
# Epoch 65/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.6384e-05 - accuracy: 1.0000
# Epoch 65: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.6384e-05 - accuracy: 1.0000 - val_loss: 1.7025e-06 - val_accuracy: 1.0000
# Epoch 66/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.5660e-05 - accuracy: 1.0000
# Epoch 66: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.5660e-05 - accuracy: 1.0000 - val_loss: 1.6503e-06 - val_accuracy: 1.0000
# Epoch 67/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0654e-04 - accuracy: 1.0000
# Epoch 67: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.0654e-04 - accuracy: 1.0000 - val_loss: 1.6056e-06 - val_accuracy: 1.0000
# Epoch 68/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.2084e-04 - accuracy: 1.0000
# Epoch 68: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 6s 2s/step - loss: 2.2084e-04 - accuracy: 1.0000 - val_loss: 1.5367e-06 - val_accuracy: 1.0000
# Epoch 69/1000
# 4/4 [==============================] - ETA: 0s - loss: 7.6115e-05 - accuracy: 1.0000
# Epoch 69: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 7.6115e-05 - accuracy: 1.0000 - val_loss: 1.4771e-06 - val_accuracy: 1.0000
# Epoch 70/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4222e-04 - accuracy: 1.0000
# Epoch 70: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.4222e-04 - accuracy: 1.0000 - val_loss: 1.4063e-06 - val_accuracy: 1.0000
# Epoch 71/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1386e-04 - accuracy: 1.0000
# Epoch 71: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.1386e-04 - accuracy: 1.0000 - val_loss: 1.3355e-06 - val_accuracy: 1.0000
# Epoch 72/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.8686e-05 - accuracy: 1.0000
# Epoch 72: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.8686e-05 - accuracy: 1.0000 - val_loss: 1.2852e-06 - val_accuracy: 1.0000
# Epoch 73/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.8794e-05 - accuracy: 1.0000
# Epoch 73: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.8794e-05 - accuracy: 1.0000 - val_loss: 1.2275e-06 - val_accuracy: 1.0000
# Epoch 74/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.2398e-04 - accuracy: 1.0000
# Epoch 74: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.2398e-04 - accuracy: 1.0000 - val_loss: 1.1902e-06 - val_accuracy: 1.0000
# Epoch 75/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.7979e-05 - accuracy: 1.0000
# Epoch 75: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 4.7979e-05 - accuracy: 1.0000 - val_loss: 1.1344e-06 - val_accuracy: 1.0000
# Epoch 76/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.1482e-05 - accuracy: 1.0000
# Epoch 76: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.1482e-05 - accuracy: 1.0000 - val_loss: 1.0990e-06 - val_accuracy: 1.0000
# Epoch 77/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.0144e-04 - accuracy: 1.0000
# Epoch 77: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.0144e-04 - accuracy: 1.0000 - val_loss: 1.0394e-06 - val_accuracy: 1.0000
# Epoch 78/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.8988e-05 - accuracy: 1.0000
# Epoch 78: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.8988e-05 - accuracy: 1.0000 - val_loss: 9.9838e-07 - val_accuracy: 1.0000
# Epoch 79/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.3974e-05 - accuracy: 1.0000
# Epoch 79: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 5.3974e-05 - accuracy: 1.0000 - val_loss: 9.5740e-07 - val_accuracy: 1.0000
# Epoch 80/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.0599e-05 - accuracy: 1.0000
# Epoch 80: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 4.0599e-05 - accuracy: 1.0000 - val_loss: 9.1642e-07 - val_accuracy: 1.0000
# Epoch 81/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.1732e-05 - accuracy: 1.0000
# Epoch 81: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.1732e-05 - accuracy: 1.0000 - val_loss: 8.8103e-07 - val_accuracy: 1.0000
# Epoch 82/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.3996e-05 - accuracy: 1.0000
# Epoch 82: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.3996e-05 - accuracy: 1.0000 - val_loss: 8.6985e-07 - val_accuracy: 1.0000
# Epoch 83/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5797e-04 - accuracy: 1.0000
# Epoch 83: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.5797e-04 - accuracy: 1.0000 - val_loss: 8.2701e-07 - val_accuracy: 1.0000
# Epoch 84/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.7674e-05 - accuracy: 1.0000
# Epoch 84: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 3.7674e-05 - accuracy: 1.0000 - val_loss: 7.9907e-07 - val_accuracy: 1.0000
# Epoch 85/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.0877e-05 - accuracy: 1.0000
# Epoch 85: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.0877e-05 - accuracy: 1.0000 - val_loss: 7.9162e-07 - val_accuracy: 1.0000
# Epoch 86/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.1850e-05 - accuracy: 1.0000
# Epoch 86: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.1850e-05 - accuracy: 1.0000 - val_loss: 7.7486e-07 - val_accuracy: 1.0000
# Epoch 87/1000
# 4/4 [==============================] - ETA: 0s - loss: 7.1881e-05 - accuracy: 1.0000
# Epoch 87: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 7.1881e-05 - accuracy: 1.0000 - val_loss: 7.4878e-07 - val_accuracy: 1.0000
# Epoch 88/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.9005e-05 - accuracy: 1.0000
# Epoch 88: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.9005e-05 - accuracy: 1.0000 - val_loss: 7.2643e-07 - val_accuracy: 1.0000
# Epoch 89/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.2559e-05 - accuracy: 1.0000
# Epoch 89: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 6.2559e-05 - accuracy: 1.0000 - val_loss: 7.0408e-07 - val_accuracy: 1.0000
# Epoch 90/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.9647e-05 - accuracy: 1.0000
# Epoch 90: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.9647e-05 - accuracy: 1.0000 - val_loss: 6.7987e-07 - val_accuracy: 1.0000
# Epoch 91/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.7843e-05 - accuracy: 1.0000
# Epoch 91: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.7843e-05 - accuracy: 1.0000 - val_loss: 6.7241e-07 - val_accuracy: 1.0000
# Epoch 92/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.6171e-05 - accuracy: 1.0000
# Epoch 92: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.6171e-05 - accuracy: 1.0000 - val_loss: 6.5938e-07 - val_accuracy: 1.0000
# Epoch 93/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.7589e-05 - accuracy: 1.0000
# Epoch 93: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 5.7589e-05 - accuracy: 1.0000 - val_loss: 6.4447e-07 - val_accuracy: 1.0000
# Epoch 94/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.3909e-05 - accuracy: 1.0000
# Epoch 94: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.3909e-05 - accuracy: 1.0000 - val_loss: 6.2212e-07 - val_accuracy: 1.0000
# Epoch 95/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1852e-04 - accuracy: 1.0000
# Epoch 95: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.1852e-04 - accuracy: 1.0000 - val_loss: 5.9418e-07 - val_accuracy: 1.0000
# Epoch 96/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.9972e-05 - accuracy: 1.0000
# Epoch 96: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.9972e-05 - accuracy: 1.0000 - val_loss: 5.5507e-07 - val_accuracy: 1.0000
# Epoch 97/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.6956e-04 - accuracy: 1.0000
# Epoch 97: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.6956e-04 - accuracy: 1.0000 - val_loss: 5.3830e-07 - val_accuracy: 1.0000
# Epoch 98/1000
# 4/4 [==============================] - ETA: 0s - loss: 8.8880e-05 - accuracy: 1.0000
# Epoch 98: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 8.8880e-05 - accuracy: 1.0000 - val_loss: 5.2154e-07 - val_accuracy: 1.0000
# Epoch 99/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.4310e-05 - accuracy: 1.0000
# Epoch 99: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.4310e-05 - accuracy: 1.0000 - val_loss: 5.0478e-07 - val_accuracy: 1.0000
# Epoch 100/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.2071e-05 - accuracy: 1.0000
# Epoch 100: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 4.2071e-05 - accuracy: 1.0000 - val_loss: 4.8615e-07 - val_accuracy: 1.0000
# Epoch 101/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.2441e-04 - accuracy: 1.0000
# Epoch 101: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.2441e-04 - accuracy: 1.0000 - val_loss: 4.5449e-07 - val_accuracy: 1.0000
# Epoch 102/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.6360e-05 - accuracy: 1.0000
# Epoch 102: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.6360e-05 - accuracy: 1.0000 - val_loss: 4.1351e-07 - val_accuracy: 1.0000
# Epoch 103/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5571e-04 - accuracy: 1.0000
# Epoch 103: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.5571e-04 - accuracy: 1.0000 - val_loss: 4.0606e-07 - val_accuracy: 1.0000
# Epoch 104/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.2027e-05 - accuracy: 1.0000
# Epoch 104: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 4.2027e-05 - accuracy: 1.0000 - val_loss: 3.9674e-07 - val_accuracy: 1.0000
# Epoch 105/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.1318e-05 - accuracy: 1.0000
# Epoch 105: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 6.1318e-05 - accuracy: 1.0000 - val_loss: 3.8743e-07 - val_accuracy: 1.0000
# Epoch 106/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.3915e-05 - accuracy: 1.0000
# Epoch 106: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.3915e-05 - accuracy: 1.0000 - val_loss: 3.8184e-07 - val_accuracy: 1.0000
# Epoch 107/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0591e-05 - accuracy: 1.0000
# Epoch 107: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.0591e-05 - accuracy: 1.0000 - val_loss: 3.6508e-07 - val_accuracy: 1.0000
# Epoch 108/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.0450e-05 - accuracy: 1.0000
# Epoch 108: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 3.0450e-05 - accuracy: 1.0000 - val_loss: 3.5577e-07 - val_accuracy: 1.0000
# Epoch 109/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.1356e-05 - accuracy: 1.0000
# Epoch 109: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.1356e-05 - accuracy: 1.0000 - val_loss: 3.3714e-07 - val_accuracy: 1.0000
# Epoch 110/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.7565e-05 - accuracy: 1.0000
# Epoch 110: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 3.7565e-05 - accuracy: 1.0000 - val_loss: 3.3714e-07 - val_accuracy: 1.0000
# Epoch 111/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.0025e-04 - accuracy: 1.0000
# Epoch 111: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.0025e-04 - accuracy: 1.0000 - val_loss: 3.3341e-07 - val_accuracy: 1.0000
# Epoch 112/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0262e-05 - accuracy: 1.0000
# Epoch 112: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.0262e-05 - accuracy: 1.0000 - val_loss: 3.1851e-07 - val_accuracy: 1.0000
# Epoch 113/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.1337e-05 - accuracy: 1.0000
# Epoch 113: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.1337e-05 - accuracy: 1.0000 - val_loss: 3.0547e-07 - val_accuracy: 1.0000
# Epoch 114/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.6164e-05 - accuracy: 1.0000
# Epoch 114: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.6164e-05 - accuracy: 1.0000 - val_loss: 3.0175e-07 - val_accuracy: 1.0000
# Epoch 115/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.9517e-05 - accuracy: 1.0000
# Epoch 115: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.9517e-05 - accuracy: 1.0000 - val_loss: 2.9802e-07 - val_accuracy: 1.0000
# Epoch 116/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.9678e-05 - accuracy: 1.0000
# Epoch 116: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.9678e-05 - accuracy: 1.0000 - val_loss: 2.8871e-07 - val_accuracy: 1.0000
# Epoch 117/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.4114e-05 - accuracy: 1.0000
# Epoch 117: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.4114e-05 - accuracy: 1.0000 - val_loss: 2.7940e-07 - val_accuracy: 1.0000
# Epoch 118/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.2829e-05 - accuracy: 1.0000
# Epoch 118: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.2829e-05 - accuracy: 1.0000 - val_loss: 2.7195e-07 - val_accuracy: 1.0000
# Epoch 119/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.0074e-05 - accuracy: 1.0000
# Epoch 119: val_loss did not improve from 0.00000
# 4/4 [==============================] - 5s 1s/step - loss: 3.0074e-05 - accuracy: 1.0000 - val_loss: 2.7195e-07 - val_accuracy: 1.0000
# Epoch 120/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.1623e-05 - accuracy: 1.0000
# Epoch 120: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.1623e-05 - accuracy: 1.0000 - val_loss: 2.7008e-07 - val_accuracy: 1.0000
# Epoch 121/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.9717e-05 - accuracy: 1.0000
# Epoch 121: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.9717e-05 - accuracy: 1.0000 - val_loss: 2.6822e-07 - val_accuracy: 1.0000
# Epoch 122/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.4839e-05 - accuracy: 1.0000
# Epoch 122: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.4839e-05 - accuracy: 1.0000 - val_loss: 2.6450e-07 - val_accuracy: 1.0000
# Epoch 123/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4735e-04 - accuracy: 1.0000
# Epoch 123: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.4735e-04 - accuracy: 1.0000 - val_loss: 2.5332e-07 - val_accuracy: 1.0000
# Epoch 124/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.2553e-05 - accuracy: 1.0000
# Epoch 124: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.2553e-05 - accuracy: 1.0000 - val_loss: 2.3097e-07 - val_accuracy: 1.0000
# Epoch 125/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.5092e-06 - accuracy: 1.0000
# Epoch 125: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 9.5092e-06 - accuracy: 1.0000 - val_loss: 2.2165e-07 - val_accuracy: 1.0000
# Epoch 126/1000
# 4/4 [==============================] - ETA: 0s - loss: 7.1627e-05 - accuracy: 1.0000
# Epoch 126: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 7.1627e-05 - accuracy: 1.0000 - val_loss: 2.1979e-07 - val_accuracy: 1.0000
# Epoch 127/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0305e-05 - accuracy: 1.0000
# Epoch 127: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.0305e-05 - accuracy: 1.0000 - val_loss: 2.1420e-07 - val_accuracy: 1.0000
# Epoch 128/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.1100e-05 - accuracy: 1.0000
# Epoch 128: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.1100e-05 - accuracy: 1.0000 - val_loss: 2.1234e-07 - val_accuracy: 1.0000
# Epoch 129/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.1431e-06 - accuracy: 1.0000
# Epoch 129: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 9.1431e-06 - accuracy: 1.0000 - val_loss: 2.1048e-07 - val_accuracy: 1.0000
# Epoch 130/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5241e-05 - accuracy: 1.0000
# Epoch 130: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.5241e-05 - accuracy: 1.0000 - val_loss: 2.0862e-07 - val_accuracy: 1.0000
# Epoch 131/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.6072e-05 - accuracy: 1.0000
# Epoch 131: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 3.6072e-05 - accuracy: 1.0000 - val_loss: 2.0489e-07 - val_accuracy: 1.0000
# Epoch 132/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.4912e-05 - accuracy: 1.0000
# Epoch 132: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 2.4912e-05 - accuracy: 1.0000 - val_loss: 2.0489e-07 - val_accuracy: 1.0000
# Epoch 133/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.2557e-05 - accuracy: 1.0000
# Epoch 133: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 2.2557e-05 - accuracy: 1.0000 - val_loss: 2.0117e-07 - val_accuracy: 1.0000
# Epoch 134/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4640e-05 - accuracy: 1.0000
# Epoch 134: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.4640e-05 - accuracy: 1.0000 - val_loss: 1.9930e-07 - val_accuracy: 1.0000
# Epoch 135/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.3427e-05 - accuracy: 1.0000
# Epoch 135: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 4.3427e-05 - accuracy: 1.0000 - val_loss: 1.9744e-07 - val_accuracy: 1.0000
# Epoch 136/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.5498e-05 - accuracy: 1.0000
# Epoch 136: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 1.5498e-05 - accuracy: 1.0000 - val_loss: 1.9744e-07 - val_accuracy: 1.0000
# Epoch 137/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1071e-05 - accuracy: 1.0000
# Epoch 137: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.1071e-05 - accuracy: 1.0000 - val_loss: 1.9372e-07 - val_accuracy: 1.0000
# Epoch 138/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.3623e-05 - accuracy: 1.0000
# Epoch 138: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.3623e-05 - accuracy: 1.0000 - val_loss: 1.9185e-07 - val_accuracy: 1.0000
# Epoch 139/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.6379e-05 - accuracy: 1.0000
# Epoch 139: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.6379e-05 - accuracy: 1.0000 - val_loss: 1.8999e-07 - val_accuracy: 1.0000
# Epoch 140/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.3258e-05 - accuracy: 1.0000
# Epoch 140: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.3258e-05 - accuracy: 1.0000 - val_loss: 1.8813e-07 - val_accuracy: 1.0000
# Epoch 141/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.4651e-06 - accuracy: 1.0000
# Epoch 141: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 5.4651e-06 - accuracy: 1.0000 - val_loss: 1.8254e-07 - val_accuracy: 1.0000
# Epoch 142/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.0955e-05 - accuracy: 1.0000
# Epoch 142: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 4.0955e-05 - accuracy: 1.0000 - val_loss: 1.8068e-07 - val_accuracy: 1.0000
# Epoch 143/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0060e-05 - accuracy: 1.0000
# Epoch 143: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.0060e-05 - accuracy: 1.0000 - val_loss: 1.7509e-07 - val_accuracy: 1.0000
# Epoch 144/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.9500e-05 - accuracy: 1.0000
# Epoch 144: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 3.9500e-05 - accuracy: 1.0000 - val_loss: 1.6950e-07 - val_accuracy: 1.0000
# Epoch 145/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.8201e-05 - accuracy: 1.0000
# Epoch 145: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.8201e-05 - accuracy: 1.0000 - val_loss: 1.6578e-07 - val_accuracy: 1.0000
# Epoch 146/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.0204e-05 - accuracy: 1.0000
# Epoch 146: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 2.0204e-05 - accuracy: 1.0000 - val_loss: 1.6019e-07 - val_accuracy: 1.0000
# Epoch 147/1000
# 4/4 [==============================] - ETA: 0s - loss: 5.3331e-05 - accuracy: 1.0000
# Epoch 147: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 5.3331e-05 - accuracy: 1.0000 - val_loss: 1.5646e-07 - val_accuracy: 1.0000
# Epoch 148/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.9026e-05 - accuracy: 1.0000
# Epoch 148: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.9026e-05 - accuracy: 1.0000 - val_loss: 1.5087e-07 - val_accuracy: 1.0000
# Epoch 149/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.0916e-05 - accuracy: 1.0000
# Epoch 149: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.0916e-05 - accuracy: 1.0000 - val_loss: 1.4715e-07 - val_accuracy: 1.0000
# Epoch 150/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4147e-05 - accuracy: 1.0000
# Epoch 150: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 1.4147e-05 - accuracy: 1.0000 - val_loss: 1.4715e-07 - val_accuracy: 1.0000
# Epoch 151/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.4832e-05 - accuracy: 1.0000
# Epoch 151: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 1.4832e-05 - accuracy: 1.0000 - val_loss: 1.4529e-07 - val_accuracy: 1.0000
# Epoch 152/1000
# 4/4 [==============================] - ETA: 0s - loss: 3.8677e-05 - accuracy: 1.0000
# Epoch 152: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 3.8677e-05 - accuracy: 1.0000 - val_loss: 1.4342e-07 - val_accuracy: 1.0000
# Epoch 153/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1933e-05 - accuracy: 1.0000
# Epoch 153: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 1.1933e-05 - accuracy: 1.0000 - val_loss: 1.4342e-07 - val_accuracy: 1.0000
# Epoch 154/1000
# 4/4 [==============================] - ETA: 0s - loss: 6.8522e-06 - accuracy: 1.0000
# Epoch 154: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 5s 1s/step - loss: 6.8522e-06 - accuracy: 1.0000 - val_loss: 1.4156e-07 - val_accuracy: 1.0000
# Epoch 155/1000
# 4/4 [==============================] - ETA: 0s - loss: 9.9367e-06 - accuracy: 1.0000
# Epoch 155: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 9.9367e-06 - accuracy: 1.0000 - val_loss: 1.4156e-07 - val_accuracy: 1.0000
# Epoch 156/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1618e-05 - accuracy: 1.0000
# Epoch 156: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.1618e-05 - accuracy: 1.0000 - val_loss: 1.3970e-07 - val_accuracy: 1.0000
# Epoch 157/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1502e-05 - accuracy: 1.0000
# Epoch 157: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 1.1502e-05 - accuracy: 1.0000 - val_loss: 1.3970e-07 - val_accuracy: 1.0000
# Epoch 158/1000
# 4/4 [==============================] - ETA: 0s - loss: 1.1417e-05 - accuracy: 1.0000
# Epoch 158: val_loss improved from 0.00000 to 0.00000, saving model to E:/Acoustic\model_1_RNN.h5
# 4/4 [==============================] - 4s 1s/step - loss: 1.1417e-05 - accuracy: 1.0000 - val_loss: 1.3597e-07 - val_accuracy: 1.0000
# Epoch 159/1000
# 4/4 [==============================] - ETA: 0s - loss: 4.3745e-05 - accuracy: 1.0000
# Epoch 159: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 4.3745e-05 - accuracy: 1.0000 - val_loss: 1.3597e-07 - val_accuracy: 1.0000
# Epoch 160/1000
# 4/4 [==============================] - ETA: 0s - loss: 8.8735e-06 - accuracy: 1.0000
# Epoch 160: val_loss did not improve from 0.00000
# 4/4 [==============================] - 4s 1s/step - loss: 8.8735e-06 - accuracy: 1.0000 - val_loss: 1.3597e-07 - val_accuracy: 1.0000
# Epoch 161/1000
# 4/4 [==============================] - ETA: 0s - loss: 2.5387e-05 - accuracy: 1.0000
# Epoch 161: val_loss did not improve from 0.00000
# 4/4 [==============================] - 5s 1s/step - loss: 2.5387e-05 - accuracy: 1.0000 - val_loss: 1.3597e-07 - val_accuracy: 1.0000
# Paper 8's model has been trained and its training history has been saved to E:/Acoustic/history_1_RNN.csv.
# 4/4 [==============================] - 2s 31ms/step - loss: 1.3369e-07 - accuracy: 1.0000
# Accuracy on test set is: 1.0
# 0:12:55.497069

# %%
# Make prediction on a random sample.
X = X_test[55]
y = y_test[55]
predict(model, X, y)

    # Save model accuracies on test set (for weight calculations later on).
accuracy = {
    "model_acc": [],
    "model_loss": [],
    "total_train_time": [],
}

accuracy["model_acc"].append(test_accuracy)
accuracy["model_loss"].append(test_error)
accuracy["total_train_time"].append(str(time))

with open(ACC_SAVE, "w") as fp:
    json.dump(accuracy, fp, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 X = X_test[55]
#       3 y = y_test[55]
# ----> 4 predict(model, X, y)
#       6     # Save model accuracies on test set (for weight calculations later on).
#       7 accuracy = {
#       8     "model_acc": [],
#       9     "model_loss": [],
#      10     "total_train_time": [],
#      11 }
#
# NameError: name 'predict' is not defined

# %%
import os
import json
import librosa
import tensorflow as tf
import numpy as np
from termcolor import colored

# %%
# Read and save parameters.
DATASET_PATH = ""  # Path of folder with testing audios.
SAVED_MODEL_PATH = "E:/Acoustic/model_1_RNN.h5"  # Path of trained model
SAMPLE_RATE = 22050  # Sample rate in Hz.
DURATION = 1  # Length of audio files fed. Measured in seconds.
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# Predictions (1 or 0)
JSON_PATH = ".../predictions.json"
# Performance scores (accuracy, precision, recall, f1 score)
JSON_PERFORMANCE = ".../model_scores.json"

# Prediction of fed audio
class _Class_Predict_Service:
    """Singleton class for keyword spotting inference with trained models.
    :param model: Trained model
    """

    model = None
    _mapping = [
        1,
        0
    ]
    _instance = None

    # Predict hard values (1 or 0).
    def predict(self, file_path):
        """
        :param file_path (str): Path to audio file to predict
        :return predicted_keyword (str): Keyword predicted by the model
        """

        # Extract mels from testing audio.
        log_mel = self.preprocess(file_path)

        log_mel = log_mel[np.newaxis, ...]

        # Get the predicted label.
        predictions = self.model.predict(log_mel)
        predicted_index = np.argmax(predictions)
        predicted_class = self._mapping[predicted_index]
        return predicted_class

    # Outputs certainty values for soft voting (1-0).
    def preprocess(self, file_path, n_mels=90, n_fft=2048, hop_length=512, num_segments=1):
        """Extract MFCCs from audio file.
        :param file_path (str): Path of audio file
        :param n_mels (int): # of mels to extract
        :param n_fft (int): Interval we consider to apply STFT. Measured in # of samples
        :param hop_length (int): Sliding window for STFT. Measured in # of samples
        """

        num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)

        # Load audio file.
        signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

        # Process segments extracting mels and storing data.
        for s in range(num_segments):
            start_sample = num_samples_per_segment * s  # s=0 --> 0
            finish_sample = start_sample + num_samples_per_segment  # s=0 --> num_samples_per_segment

            # Extract mel specs.
            mel = librosa.feature.melspectrogram(signal[start_sample:finish_sample], sr=sr, n_mels=n_mels, n_fft=n_fft,
                                                 hop_length=hop_length)
            log_mel = librosa.power_to_db(mel)

        return log_mel.T


def Keyword_Spotting_Service():
    """Factory function for Keyword_Spotting_Service class.
    :return _Keyword_Spotting_Service._instance (_Keyword_Spotting_Service):
    """

    # Ensure an instance is created only the first time the factory function is called.
    if _Class_Predict_Service._instance is None:
        _Class_Predict_Service._instance = _Class_Predict_Service()
        _Class_Predict_Service.model = tf.keras.models.load_model(SAVED_MODEL_PATH)
    return _Class_Predict_Service._instance


# Saving results into a json file.
def save_mfcc(dataset_path, json_path):

    # Dictionary to store data.
    data = {
        "mapping": [],  # Maps different class labels --> background is mapped to 0.
        "names": [],
        "results": [],  # mels are the training input, labels are the target.
    }

    # Loop through all the classes.
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # Ensure that we're not at the root level.
        if dirpath is not dataset_path:

            # Save the semantic label.
            dirpath_components = dirpath.split("/")  # class/background => ["class", "background"]
            semantic_label = dirpath_components[-1]  # considering only the last value
            data["mapping"].append(semantic_label)
            print("\nProcessing {}".format(semantic_label))

            # Process files for a specific class.
            for f in filenames:
                file_path = os.path.join(dirpath, f)

                # Create 2 instances of the keyword spotting service.
                kss = Keyword_Spotting_Service()
                kss1 = Keyword_Spotting_Service()

                # Check that different instances of the keyword spotting service point back to the same object.
                assert kss is kss1

                # Classify unseen audio.
                keyword = kss.predict(file_path)

                # Store mel for segment if it has the expected length.
                data["names"].append(f)
                data["results"].append(keyword)
                print("{}".format(file_path))

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)


# Calculating performance scores (accuracy, precision, recall, f-score).
def performance_calcs(performance_path):
    # Dictionary to store model performance results.
    perfromance = {
        "TP": [],
        "FN": [],
        "TN": [],
        "FP": [],
        "Accuracy": [],
        "Precision": [],
        "Recall": [],
        "F1 Score": [],
    }

    with open(JSON_PATH, "r") as fp:
        data = json.load(fp)

    # Convert lists to numpy arrays.
    y = np.array(data["results"])

    a = float(sum(y[0:int(len(y) / 2)]))
    b = float(sum(y[int(len(y) / 2):int(len(y))]))

    # Calculating TP, TN, FP, FN.
    TP = a
    FN = int(len(y) / 2) - a
    FP = b
    TN = int(len(y) / 2) - b

    # Performance result calcs.
    Accuracy = (TP + TN) / (TP + TN + FN + FP)
    Precision = TP / (TP + FP)
    Recall = TP / (TP + FN)
    F1 = (2 * Precision * Recall) / (Precision + Recall)

    perfromance["TP"].append(TP)
    perfromance["FN"].append(FN)
    perfromance["TN"].append(TN)
    perfromance["FP"].append(FP)
    perfromance["Accuracy"].append(Accuracy)
    perfromance["Precision"].append(Precision)
    perfromance["Recall"].append(Recall)
    perfromance["F1 Score"].append(F1)

    with open(performance_path, "w") as fp:
        json.dump(perfromance, fp, indent=4)


if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH)
    performance_calcs(JSON_PERFORMANCE)

    print(
        colored("Paper 8's model performance scores have been saved to {}.".format(JSON_PERFORMANCE), "green"))
